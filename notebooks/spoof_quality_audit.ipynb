# %% [markdown]
# # Spoof Quality Audit
#
# Placeholder (Week 3). Manual 50-clip listening audit; failure tagging; quality stats.
#
# Exploration only — no pipeline logic lives in notebooks (see repo rule 1).
