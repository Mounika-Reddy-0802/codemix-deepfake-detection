# %% [markdown]
# # EDA — Corpora
#
# Placeholder (Week 2+). Durations, sample rates, speaker counts, label balance per corpus.
#
# Exploration only — no pipeline logic lives in notebooks (see repo rule 1).
