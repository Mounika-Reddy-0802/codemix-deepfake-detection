# %% [markdown]
# # Error Analysis
#
# Placeholder (Week 6+). Which utterances fool the detector; which bonafide clips get flagged.
#
# Exploration only — no pipeline logic lives in notebooks (see repo rule 1).
